# %% [markdown]
# # Check Setup

# %%
import sys
import os
import numpy as np
import pandas as pd
import sklearn
import spacy
import nltk
import langdetect

# %%
print(f"{sys.version=}")  # Py version of the current environment
print(f"{os.getcwd()=}") ## this should be project's root folder
# Out:
# sys.version='3.10.9 | packaged by Anaconda, Inc. | (main, Mar  1 2023, 18:18:15) [MSC v.1916 64 bit (AMD64)]'
# os.getcwd()='c:\\Users\\manuelalberto.romero\\Documents\\repos\\dslabs\\dslab-nlp-dl'

# %%
print(f"{sklearn.__version__=}")
print(f"{nltk.__version__=}")
print(f"{pd.__version__=}")
print(f"{spacy.__version__=}")
# Out:
# sklearn.__version__='1.6.1'
# nltk.__version__='3.9.1'
# pd.__version__='2.2.2'
# spacy.__version__='3.8.7'
